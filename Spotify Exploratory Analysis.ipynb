# %% [markdown]
# # 𝄞 SPOTIFY EXPLORATORY ANALYSIS

# %% [markdown]
# <h3>IMPORTING ALL THE DATA FILES AND DIFFERENT LIBRARIES</h3>

# %%
import pandas as pd
import numpy as np

# %%
# For using SQL in Jupyter
from pandasql import sqldf
pysql = lambda q: sqldf(q, globals())

# %%
# For Data Visualization
# %matplotlib notebook
import matplotlib.pyplot as plt
import seaborn as sns

# %%
track_data = pd.read_csv('E:/SQL Projects/Spotify/data.csv')

# %%
data_by_artist = pd.read_csv('E:/SQL Projects/Spotify/data_by_artist.csv')

# %%
data_by_genre = pd.read_csv('E:/SQL Projects/Spotify/data_by_genres.csv')

# %%
data_w_genre = pd.read_csv('E:/SQL Projects/Spotify/data_w_genres.csv')

# %% [markdown]
# <h3>INFORMATION ON DIFFERENT DATA TABLES</h3>

# %%
track_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 174389 entries, 0 to 174388
# Data columns (total 19 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   acousticness      174389 non-null  float64
#  1   artists           174389 non-null  object
#  2   danceability      174389 non-null  float64
#  3   duration_ms       174389 non-null  int64
#  4   energy            174389 non-null  float64
#  5   explicit          174389 non-null  int64
#  6   id                174389 non-null  object
#  7   instrumentalness  174389 non-null  float64
#  8   key               174389 non-null  int64
#  9   liveness          174389 non-null  float64
#  10  loudness          174389 non-null  float64
#  11  mode              174389 non-null  int64
#  12  name              174389 non-null  object
#  13  popularity        174389 non-null  int64
#  14  release_date      174389 non-null  object
#  15  speechiness       174389 non-null  float64
# ...

# %%
data_by_artist.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32539 entries, 0 to 32538
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   artists           32539 non-null  object
#  1   acousticness      32539 non-null  float64
#  2   danceability      32539 non-null  float64
#  3   duration_ms       32539 non-null  float64
#  4   energy            32539 non-null  float64
#  5   instrumentalness  32539 non-null  float64
#  6   liveness          32539 non-null  float64
#  7   loudness          32539 non-null  float64
#  8   speechiness       32539 non-null  float64
#  9   tempo             32539 non-null  float64
#  10  valence           32539 non-null  float64
#  11  popularity        32539 non-null  float64
#  12  key               32539 non-null  int64
#  13  mode              32539 non-null  int64
#  14  count             32539 non-null  int64
# dtypes: float64(11), int64(3), object(1)
# ...

# %%
data_by_genre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3232 entries, 0 to 3231
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   genres            3232 non-null   object
#  1   acousticness      3232 non-null   float64
#  2   danceability      3232 non-null   float64
#  3   duration_ms       3232 non-null   float64
#  4   energy            3232 non-null   float64
#  5   instrumentalness  3232 non-null   float64
#  6   liveness          3232 non-null   float64
#  7   loudness          3232 non-null   float64
#  8   speechiness       3232 non-null   float64
#  9   tempo             3232 non-null   float64
#  10  valence           3232 non-null   float64
#  11  popularity        3232 non-null   float64
#  12  key               3232 non-null   int64
#  13  mode              3232 non-null   int64
# dtypes: float64(11), int64(2), object(1)
# memory usage: 353.6+ KB

# %%
data_w_genre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32539 entries, 0 to 32538
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   artists           32539 non-null  object
#  1   acousticness      32539 non-null  float64
#  2   danceability      32539 non-null  float64
#  3   duration_ms       32539 non-null  float64
#  4   energy            32539 non-null  float64
#  5   instrumentalness  32539 non-null  float64
#  6   liveness          32539 non-null  float64
#  7   loudness          32539 non-null  float64
#  8   speechiness       32539 non-null  float64
#  9   tempo             32539 non-null  float64
#  10  valence           32539 non-null  float64
#  11  popularity        32539 non-null  float64
#  12  key               32539 non-null  int64
#  13  mode              32539 non-null  int64
#  14  count             32539 non-null  int64
#  15  genres            32539 non-null  object
# ...

# %% [markdown]
# <h3>INFORMATION ON DIFFERENT TERMS USED</h3>

# %% [markdown]
# **Acousticness** -
# This value describes how "acoustic" the song is.
# Value above 0.66: The song mostly (or completely) contains words
# Value between 0.33 and 0.66: The song contains both words and music
# Value below 0.33: The song mostly (or completely) contains music
#
# **Danceability** -
# How suitable a song is for dancing.
# Based on a combination of musical elements including tempo, rhythm, stability, beat strength and overall   regularity
#
# **Energy** -
# Perceptual measure of intensity and activity.
#
# **Instrumentalness** -
# Predicts whether the song contains no vocals.
#
# **Liveness** -
# Whether the song was done live or in a studio. Higher the value, greater the probability of the song recorded live.
#
# **Loudness** -
# Overall loudness of a song in decibel.
#
# **Valence** -
# Describes the musical positivess conveyed by the song.
# Higher the valence, greater the positiveness in the songs.
#
# **Tempo** -
# Overall tempo of the song in bpm.
#
# **Speechiness** -
# Detects the presence of vocals in a track.
#
# **Key**-
# The estimated overall key of the track. Integers map to pitches using standard Pitch Class otation. E.g. 0 = C, 1 = C♯/D♭, 2 = D, and so on.
#
# **Mode** -
# Indicates modality (major or minor) of the song. Major is 1 and minor is 0.
#
# **Time Signature** -
# An estimated overall time signature of a track. The time signature (meter) is a notational convention to specify how many beats are in each bar (or measure).

# %% [markdown]
# <h3>SOME INFO AROUND THE release_date</h3>

# %% [markdown]
# Changing the datatype for release_date in track_data table

# %%
track_data['release_date']=pd.to_datetime(track_data['release_date'])

# %%
print('The release date of the oldest track in the dataset: ',track_data['release_date'].min())
print('The release date of the latest track in the dataset: ',track_data['release_date'].max())
# Out:
# The release date of the oldest track in the dataset:  1920-01-01 00:00:00
# The release date of the latest track in the dataset:  2021-01-23 00:00:00

# %%
track_data['release_date'].hist(bins=100)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# As we can see, the highest number of songs in this dataset is between years 2015-2021

# %% [markdown]
# ### EXPLORING THE FIRST TABLE (TRACK_DATA)

# %% [markdown]
# <h4>First impression of the table</h4>

# %%
pysql('SELECT * FROM track_data LIMIT 5')
# Out:
#    acousticness                    artists  danceability  duration_ms  energy  \
# 0      0.991000            ['Mamie Smith']         0.598       168333   0.224
# 1      0.643000  ["Screamin' Jay Hawkins"]         0.852       150200   0.517
# 2      0.993000            ['Mamie Smith']         0.647       163827   0.186
# 3      0.000173        ['Oscar Velazquez']         0.730       422087   0.798
# 4      0.295000                   ['Mixe']         0.704       165224   0.707
#
#    explicit                      id  instrumentalness  key  liveness  \
# 0         0  0cS0A1fUEUd1EW3FcF8AEI          0.000522    5    0.3790
# 1         0  0hbkKFIJm7Z05H8Zl9w30f          0.026400    5    0.0809
# 2         0  11m7laMUgmOKqI3oYzuhne          0.000018    0    0.5190
# 3         0  19Lc5SfJJ5O1oaxY0fpwfh          0.801000    2    0.1280
# 4         1  2hJjbsLCytGsnAHfdsLejp          0.000246   10    0.4020
#
#    loudness  mode                                               name  \
# ...

# %%
track_data.drop(['key','mode','year','explicit'],axis=1).describe().transpose().sort_index()
# Out:
#                      count           mean            std     min          25%  \
# acousticness      174389.0       0.499228       0.379936     0.0       0.0877
# danceability      174389.0       0.536758       0.176025     0.0       0.4140
# duration_ms       174389.0  232810.032026  148395.797680  4937.0  166133.0000
# energy            174389.0       0.482721       0.272685     0.0       0.2490
# instrumentalness  174389.0       0.197252       0.334574     0.0       0.0000
# liveness          174389.0       0.211123       0.180493     0.0       0.0992
# loudness          174389.0     -11.750865       5.691591   -60.0     -14.9080
# popularity        174389.0      25.693381      21.872740     0.0       1.0000
# speechiness       174389.0       0.105729       0.182260     0.0       0.0352
# tempo             174389.0     117.006500      30.254178     0.0      93.9310
# valence           174389.0       0.524533       0.264477     0.0       0.3110
#
# ...

# %%
plt.figure(figsize=(20,10))
plt.subplot(321)
sns.distplot(track_data['danceability'])
plt.subplot(322)
sns.distplot(track_data['duration_ms']*10**6)
plt.subplot(323)
sns.distplot(track_data['energy'])
plt.subplot(324)
sns.distplot(track_data['liveness'])
plt.subplot(325)
sns.distplot(track_data['loudness'])
plt.subplot(326)
sns.distplot(track_data['instrumentalness'])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="2000">

# %%
plt.figure(figsize=(20,10))
plt.subplot(321)
sns.distplot(track_data['acousticness'])
plt.subplot(322)
sns.distplot(track_data['popularity'])
plt.subplot(323)
sns.distplot(track_data['speechiness'])
plt.subplot(324)
sns.distplot(track_data['tempo'])
plt.subplot(325)
sns.distplot(track_data['valence'])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="2000">

# %%
plt.figure(figsize=(14,8))
sns.set(style="whitegrid")
corr = track_data.corr()
cmap="YlGnBu"
sns.heatmap(corr,annot=True,cmap=cmap)

x = plt.gca().xaxis
for item in x.get_ticklabels():
    item.set_rotation(45)

plt.subplots_adjust(bottom=0.25)
# Out:
# <img src="data:image/png;base64,..." width="1400">

# %% [markdown]
# <h4>How did different features of the songs change with years?</h4>

# %%
plt.figure(figsize=(14,7))
sns.set(style="whitegrid")
columns = ['acousticness','instrumentalness','danceability','energy','speechiness','valence']
for col in columns:
    x = track_data.groupby("year")[col].mean()
    ax= sns.lineplot(x=x.index,y=x,label=col)
ax.set_title('How did different song features changed over the years?')
ax.set_ylabel('Feature values')
ax.set_xlabel('Year')
plt.legend(loc=1, frameon=False)
# Out:
# <img src="data:image/png;base64,..." width="1400">

# %%
plt.figure(figsize=(14,7))
sns.set(style="whitegrid")
columns = ['loudness']
for col in columns:
    x = track_data.groupby("year")[col].mean()
    ax= sns.lineplot(x=x.index,y=x)
ax.set_title('How did loudness changed over the years?')
ax.set_ylabel('Loudness value')
ax.set_xlabel('Year')
# Out:
# <img src="data:image/png;base64,..." width="1400">
# Text(0.5, 0, 'Year')

# %% [markdown]
# <h4><u>Oldest song in the dataset</u></h4>

# %%
pysql('SELECT * FROM track_data ORDER BY release_date ASC LIMIT 1')
# Out:
#    acousticness          artists  danceability  duration_ms  energy  explicit  \
# 0         0.991  ['Mamie Smith']         0.598       168333   0.224         0
#
#                        id  instrumentalness  key  liveness  loudness  mode  \
# 0  0cS0A1fUEUd1EW3FcF8AEI          0.000522    5     0.379   -12.628     0
#
#                        name  popularity                release_date  \
# 0  Keep A Song In Your Soul          12  1920-01-01 00:00:00.000000
#
#    speechiness    tempo  valence  year
# 0       0.0936  149.976    0.634  1920

# %% [markdown]
# <h4><u>Latest song added in the dataset</u></h4>

# %%
pysql('SELECT * FROM track_data ORDER BY release_date DESC LIMIT 1')
# Out:
#    acousticness                                            artists  \
# 0         0.964  ['Mysterious World Music', 'Relaxing Zen Music...
#
#    danceability  duration_ms  energy  explicit                      id  \
# 0         0.765       195717  0.0145         0  7qzF2z1R1YQc5BhZPefFC0
#
#    instrumentalness  key  liveness  loudness  mode       name  popularity  \
# 0             0.931    5    0.0915   -13.783     0  Last Year           0
#
#                  release_date  speechiness   tempo  valence  year
# 0  2021-01-23 00:00:00.000000       0.0754  77.934    0.493  2021

# %% [markdown]
# <h3><u>Explicitness of the tracks</u></h3>

# %%
k=0
l=0
exp=[]
for i in track_data['explicit']:
    if i==1:
        k=k+1
    else:
        l=l+1
exp.append(k)
exp.append(l)

y=np.array(exp)
ylabels = ['explicit','non-explicit']
yexplode=[0.2,0]
ycolors=['#D0114D','#D5527D']

plt.figure()
plt.pie(y,labels=ylabels,colors=ycolors,explode=yexplode,shadow=True)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# <h4>How do the features of the track differentiate as according to their explicit-ness?</h4>

# %%
pysql('SELECT explicit, AVG(acousticness), AVG(loudness), AVG(instrumentalness), AVG(danceability), AVG(speechiness), AVG(popularity), AVG(mode), AVG(valence) FROM track_data WHERE explicit=0 UNION SELECT explicit, AVG(acousticness), AVG(loudness), AVG(instrumentalness), AVG(danceability), AVG(speechiness), AVG(popularity), AVG(mode), AVG(valence) FROM track_data WHERE explicit=1')
# Out:
#    explicit  AVG(acousticness)  AVG(loudness)  AVG(instrumentalness)  \
# 0         0           0.520615     -11.914384               0.209068
# 1         1           0.206725      -9.514461               0.035647
#
#    AVG(danceability)  AVG(speechiness)  AVG(popularity)  AVG(mode)  \
# 0           0.527198          0.088289        24.791166   0.710111
# 1           0.667501          0.344251        38.032739   0.596701
#
#    AVG(valence)
# 0      0.525196
# 1      0.515461

# %% [markdown]
# <h3>Top 20 artists according to nummber of songs they featured in</h3>

# %%
l = []
for i in track_data.artists:
    a=i[2:-2]
    l.append(a)
l = list(set(l))
lst = []
for i in l:
    res = i.strip('][').split(', ')
    lst.append(res)
d=[]
for i in lst:
    for j in i:
        d.append(j)
dff=pd.DataFrame(d)
dff = dff[0].value_counts()

dff = dff[:20, ]
plt.figure(figsize = (9.5, 6))
sns.barplot(dff.values, dff.index, alpha = 0.9,palette=("spring_d"))
plt.title("Top 20 Artists")
plt.ylabel("Artists")
plt.xlabel("Number of tracks")
plt.show()
plt.subplots_adjust(left=0.27)
# Out:
# <img src="data:image/png;base64,..." width="949.6">

# %% [markdown]
# <H3>EXPLORING THE SECOND TABLE (DATA_BY_ARTIST)</H3>

# %% [markdown]
# <h4>First impression of the table</h4>

# %%
pysql('SELECT * FROM data_by_artist LIMIT 10')
# Out:
#                                              artists  acousticness  \
# 0                   "Cats" 1981 Original London Cast      0.598500
# 1                          "Cats" 1983 Broadway Cast      0.862538
# 2        "Fiddler On The Roof” Motion Picture Chorus      0.856571
# 3     "Fiddler On The Roof” Motion Picture Orchestra      0.884926
# 4  "Joseph And The Amazing Technicolor Dreamcoat"...      0.510714
# 5  "Joseph And The Amazing Technicolor Dreamcoat"...      0.591167
# 6                             "Mama" Helen Teagarden      0.725000
# 7                            "Test for Victor Young"      0.927000
# 8                                "Weird Al" Yankovic      0.186821
# 9                                             $0dg0d      0.110000
#
#    danceability    duration_ms    energy  instrumentalness  liveness  \
# 0      0.470100  267072.000000  0.376203          0.010261  0.283050
# 1      0.441731  287280.000000  0.406808          0.081158  0.315215
# ...

# %% [markdown]
# <h4>Top 5 most popular artists</h4>

# %% [markdown]
# <h5>Based on popularity</h5>

# %%
pysql('SELECT artists FROM data_by_artist ORDER BY popularity DESC LIMIT 5')
# Out:
#       artists
# 0          CJ
# 1        Boza
# 2  Joel Corry
# 3        Juhn
# 4   Lele Pons

# %% [markdown]
# <h5>Based on danceability</h5>

# %%
pysql('SELECT artists FROM data_by_artist ORDER BY danceability DESC LIMIT 5')
# Out:
#             artists
# 0  Leonardo La Mark
# 1     Rio Dela Duna
# 2    Spooner Street
# 3          Young Bo
# 4    Zigmund Slezak

# %% [markdown]
# <h5>Based on speechiness</h5>

# %%
pysql('SELECT artists FROM data_by_artist ORDER BY speechiness DESC LIMIT 5')
# Out:
#               artists
# 0          Eva Mattes
# 1          Harper Lee
# 2     Francis Blanche
# 3          Pierre Dac
# 4  Christian Brückner

# %% [markdown]
# <h3>EXPLORING THE THIRD TABLE (DATA_BY_GENRE)</h3>

# %% [markdown]
# <h4>First impression of the table</h4>

# %%
pysql('SELECT * FROM data_by_genre LIMIT 10')
# Out:
#                    genres  acousticness  danceability   duration_ms    energy  \
# 0  21st century classical      0.754600      0.284100  3.525932e+05  0.159580
# 1                   432hz      0.485515      0.312000  1.047430e+06  0.391678
# 2                   8-bit      0.028900      0.673000  1.334540e+05  0.950000
# 3                      []      0.535793      0.546937  2.495312e+05  0.485430
# 4              a cappella      0.694276      0.516172  2.018391e+05  0.330533
# 5                abstract      0.411262      0.473600  3.660984e+05  0.479400
# 6          abstract beats      0.459000      0.669000  1.748670e+05  0.735000
# 7        abstract hip hop      0.297353      0.725274  2.282049e+05  0.726844
# 8            abstract idm      0.995000      0.174000  5.805330e+05  0.002910
# 9               accordeon      0.598750      0.442000  1.654800e+05  0.314000
#
#    instrumentalness  liveness   loudness  speechiness       tempo   valence  \
# ...

# %% [markdown]
# <h4>Genre Ranking</h4>

# %% [markdown]
# <h5>Based on popularity</h5>

# %%
pysql('SELECT genres,popularity FROM data_by_genre ORDER BY popularity DESC LIMIT 5')
# Out:
#                genres  popularity
# 0  chinese electropop        79.0
# 1  korean mask singer        78.0
# 2       dutch rap pop        77.0
# 3                yaoi        77.0
# 4             dong-yo        76.0

# %% [markdown]
# <h5>Based on Valence</h5>

# %%
pysql('SELECT genres,valence FROM data_by_genre ORDER BY valence DESC LIMIT 5')
# Out:
#               genres  valence
# 0              8-bit   0.9970
# 1    classic iskelma   0.9754
# 2  swedish eurodance   0.9690
# 3        trio cubano   0.9670
# 4       beninese pop   0.9660

# %% [markdown]
# <h5>Based on acousticness</h5>

# %%
pysql('SELECT genres,acousticness FROM data_by_genre ORDER BY acousticness DESC LIMIT 5')
# Out:
#                              genres  acousticness
# 0  hungarian contemporary classical      0.996000
# 1             dutch classical piano      0.995667
# 2                      abstract idm      0.995000
# 3           belgian classical piano      0.995000
# 4                         blasmusik      0.995000

# %% [markdown]
# <H3>EXPLORING THE FOURTH TABLE (DATA_W_GENRE)</H3>

# %% [markdown]
# <h4>First impression of the table</h4>

# %%
pysql('SELECT * FROM data_w_genre LIMIT 5')
# Out:
#                                              artists  acousticness  \
# 0                   "Cats" 1981 Original London Cast      0.598500
# 1                          "Cats" 1983 Broadway Cast      0.862538
# 2        "Fiddler On The Roof” Motion Picture Chorus      0.856571
# 3     "Fiddler On The Roof” Motion Picture Orchestra      0.884926
# 4  "Joseph And The Amazing Technicolor Dreamcoat"...      0.510714
#
#    danceability    duration_ms    energy  instrumentalness  liveness  \
# 0      0.470100  267072.000000  0.376203          0.010261  0.283050
# 1      0.441731  287280.000000  0.406808          0.081158  0.315215
# 2      0.348286  328920.000000  0.286571          0.024593  0.325786
# 3      0.425074  262890.962963  0.245770          0.073587  0.275481
# 4      0.467143  270436.142857  0.488286          0.009400  0.195000
#
#     loudness  speechiness       tempo   valence  popularity  key  mode  count  \
# ...

# %% [markdown]
# <h4>Genre-less tracks</h4>

# %%
k=0
l=0
for tracks in data_w_genre['genres']:
    if tracks=='[]':
        l+=1
        k+=1
    else:
        k+=1
print("Out of ",k," tracks, ",l," tracks are genre-less")
# Out:
# Out of  32539  tracks,  13563  tracks are genre-less

# %% [markdown]
# <h4>Popularity (by feature) of genres</h4>

# %%
l = []
for i in data_w_genre['genres']:
    a=i[2:-2]
    l.append(a)
l = list(set(l))
lst = []
for i in l:
    res = i.strip('][').split(', ')
    lst.append(res)
d=[]
for i in lst:
    for j in i:
        d.append(j)
dff=pd.DataFrame(d)
dff = dff[0].value_counts()

dff = dff[:20, ]
plt.figure(figsize = (9.5, 6))
sns.barplot(dff.values, dff.index, alpha = 0.9,palette=("spring_d"))
plt.title("Top 20 Genres")
plt.ylabel("Genres")
plt.xlabel("Number of tracks")
plt.show()
plt.subplots_adjust(left=0.27)
# Out:
# <img src="data:image/png;base64,..." width="949.6">

# %% [markdown]
# <h2>CONCLUSION</h2>

# %% [markdown]
# 1. In figure-3, we can see that there are strong correlation between energy & loudness (0.78), danceability & valence (0.54) and popularity & year (0.51). We can infer that recency bias is affecting the popularity values.
# 2. In figure-4, we can see that over time acousticness of the tracks has decreased significantly. Other than acousticness, energy of tracks has seen a significant change over time, becoming more energetic. Rest of the features of tracks have not seen significant change.
#     From the period of 1920 to around 1950, owes to the lesser number of track records as compared to recent times.
# 3. From the 'explicit-ness of tracks', we can see that on an average explicit tracks are significantly lesser _acoustic_ and contains more vocal than the non-explicit songs and explicit songs are also more popular than the non-explicit tracks. But, on an average, both explicit and non-explicit tracks have similar positivity score (valence).
